# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from tqdm import tqdm
import random
import pandas as pd

# %%
from sklearn.datasets import load_files
import numpy as np
DATADIR = "../dataset/fruits-360/Training"
DATADIR_test = "../dataset/fruits-360/Test"

CATEGORIES = ["Apple Braeburn","Apple Crimson Snow","Apple Golden 1","Apple Golden 2","Apple Golden 3",
              "Apple Granny Smith","Apple Pink Lady","Apple Red 1", "Apple Red 2","Apple Red 3","Apple Red Delicious",
              "Apple Red Yellow 1","Apple Red Yellow 2","Banana",
              "Plum","Plum 2", "Plum 3",
             "Pepper Yellow","Pepper Red","Pepper Green",
              "Cherry 1", "Cherry 2", "Cherry Rainier", "Cherry Wax Black", "Cherry Wax Red","Cherry Wax Yellow",
              "Grape Blue", "Grape Pink", "Grape White", "Grape White 2", "Grape White 3", "Grape White 4",
            "Tomato 1","Tomato 2","Tomato 3","Tomato 4","Tomato Yellow","Tomato Maroon",
            "Pear","Pear Abate","Pear Forelle","Pear Kaiser","Pear Monster","Pear Red","Pear Williams",
             "Peach","Peach 2","Peach Flat",
             "Potato Red", "Potato Red Washed","Potato White","Potato Sweet"
             ]

##TYPES = ["Apple", "Banana", "Plum", "Pepper", "Cherry", "Grape", "Tomato", "Potato", "Pear", "Peach"]
TYPES = ["Apple", "Banana", "Plum", "Pepper", "Cherry", "Grape", "Tomato", "Potato", "Pear", "Peach"]
fruits= {}
for cat in CATEGORIES:
    for typ in TYPES:
        if(cat.startswith(typ)):
            fruits[cat] = typ

# %%
def load_dataset(dire):
    lis_files = []
    lis_num_lab =[]
    lis_name_lab = []
    for category in CATEGORIES:
        path = os.path.join(dire,category)
        class_num =TYPES.index(fruits[category])

        class_name = fruits[category]
        for img in tqdm(os.listdir(path)):
               # print("OK: ",os.path.join(path,img) )
                lis_files.append(os.path.join(path,img))
                lis_name_lab.append(class_name)
                lis_num_lab.append(class_num)
                #print("path:  ",os.path.join(path,img)," \n Name: ",class_name," \n Id: ",class_num)

    return pd.DataFrame(list(zip(lis_files,lis_num_lab,lis_name_lab)),columns=('path','label_id',"label_name"))

all_train = load_dataset(DATADIR)
all_test = load_dataset(DATADIR_test)
#x_train, y_train,target_labels = load_dataset(DATADIR)
#x_test, y_test,_ = load_dataset(DATADIR_test)
#print('Loading complete!')

#print('Training set size : ' , x_train.shape[0])
#print('Testing set size : ', x_test.shape[0])
# Out:
# 100%|████████████████████████████████████| 492/492 [00:00<00:00, 164758.29it/s]
# 100%|████████████████████████████████████| 444/444 [00:00<00:00, 220413.18it/s]
# 100%|████████████████████████████████████| 480/480 [00:00<00:00, 481412.22it/s]
# 100%|████████████████████████████████████| 492/492 [00:00<00:00, 246164.57it/s]
# 100%|████████████████████████████████████| 481/481 [00:00<00:00, 240574.79it/s]
# 100%|████████████████████████████████████| 492/492 [00:00<00:00, 244676.02it/s]
# 100%|████████████████████████████████████| 456/456 [00:00<00:00, 228016.53it/s]
# 100%|████████████████████████████████████| 492/492 [00:00<00:00, 247849.82it/s]
# 100%|████████████████████████████████████| 492/492 [00:00<00:00, 246135.21it/s]
# 100%|████████████████████████████████████| 429/429 [00:00<00:00, 429235.79it/s]
# 100%|████████████████████████████████████| 490/490 [00:00<00:00, 245163.90it/s]
# 100%|████████████████████████████████████| 492/492 [00:00<00:00, 246105.85it/s]
# 100%|████████████████████████████████████| 672/672 [00:00<00:00, 224105.29it/s]
# 100%|████████████████████████████████████| 490/490 [00:00<00:00, 490269.31it/s]
# 100%|████████████████████████████████████| 447/447 [00:00<00:00, 223596.17it/s]
# 100%|████████████████████████████████████| 420/420 [00:00<00:00, 210040.26it/s]
# 100%|████████████████████████████████████| 900/900 [00:00<00:00, 300141.02it/s]
# 100%|████████████████████████████████████| 666/666 [00:00<00:00, 333183.02it/s]
# 100%|████████████████████████████████████| 666/666 [00:00<00:00, 222122.02it/s]
# 100%|████████████████████████████████████| 444/444 [00:00<00:00, 222042.56it/s]
# 100%|████████████████████████████████████| 492/492 [00:00<00:00, 246105.85it/s]
# 100%|████████████████████████████████████| 738/738 [00:00<00:00, 246174.36it/s]
# 100%|████████████████████████████████████| 738/738 [00:00<00:00, 369246.85it/s]
# 100%|████████████████████████████████████| 492/492 [00:00<00:00, 246076.50it/s]
# 100%|████████████████████████████████████| 492/492 [00:00<00:00, 246105.85it/s]
# 100%|████████████████████████████████████| 492/492 [00:00<00:00, 492622.96it/s]
# 100%|████████████████████████████████████| 984/984 [00:00<00:00, 246105.85it/s]
# 100%|████████████████████████████████████| 492/492 [00:00<00:00, 246193.94it/s]
# 100%|████████████████████████████████████| 490/490 [00:00<00:00, 245134.66it/s]
# 100%|████████████████████████████████████| 490/490 [00:00<00:00, 245046.97it/s]
# 100%|████████████████████████████████████| 492/492 [00:00<00:00, 246076.50it/s]
# 100%|████████████████████████████████████| 471/471 [00:00<00:00, 471371.32it/s]
# 100%|████████████████████████████████████| 738/738 [00:00<00:00, 369246.85it/s]
# 100%|████████████████████████████████████| 672/672 [00:00<00:00, 336104.49it/s]
# 100%|████████████████████████████████████| 738/738 [00:00<00:00, 369202.81it/s]
# 100%|████████████████████████████████████| 479/479 [00:00<00:00, 159754.42it/s]
# 100%|████████████████████████████████████| 459/459 [00:00<00:00, 229626.14it/s]
# 100%|████████████████████████████████████| 367/367 [00:00<00:00, 366939.11it/s]
# 100%|████████████████████████████████████| 492/492 [00:00<00:00, 246105.85it/s]
# 100%|████████████████████████████████████| 490/490 [00:00<00:00, 245105.42it/s]
# 100%|████████████████████████████████████| 702/702 [00:00<00:00, 234110.00it/s]
# 100%|████████████████████████████████████| 300/300 [00:00<00:00, 300093.30it/s]
# 100%|████████████████████████████████████| 490/490 [00:00<00:00, 245046.97it/s]
# 100%|████████████████████████████████████| 666/666 [00:00<00:00, 222139.68it/s]
# 100%|████████████████████████████████████| 490/490 [00:00<00:00, 245105.42it/s]
# 100%|████████████████████████████████████| 492/492 [00:00<00:00, 246105.85it/s]
# 100%|████████████████████████████████████| 738/738 [00:00<00:00, 369026.75it/s]
# 100%|████████████████████████████████████| 492/492 [00:00<00:00, 246076.50it/s]
# 100%|████████████████████████████████████| 450/450 [00:00<00:00, 225069.97it/s]
# 100%|████████████████████████████████████| 453/453 [00:00<00:00, 151034.95it/s]
# 100%|████████████████████████████████████| 450/450 [00:00<00:00, 450032.62it/s]
# 100%|████████████████████████████████████| 450/450 [00:00<00:00, 225043.14it/s]
# 100%|████████████████████████████████████████████████| 164/164 [00:00<?, ?it/s]
# 100%|████████████████████████████████████| 148/148 [00:00<00:00, 148187.39it/s]
# 100%|████████████████████████████████████████████████| 160/160 [00:00<?, ?it/s]
# 100%|████████████████████████████████████| 164/164 [00:00<00:00, 164207.65it/s]
# 100%|████████████████████████████████████| 161/161 [00:00<00:00, 161011.67it/s]
# 100%|████████████████████████████████████| 164/164 [00:00<00:00, 164051.00it/s]
# 100%|████████████████████████████████████| 152/152 [00:00<00:00, 152083.54it/s]
# 100%|████████████████████████████████████| 164/164 [00:00<00:00, 163972.79it/s]
# 100%|████████████████████████████████████| 164/164 [00:00<00:00, 169258.33it/s]
# 100%|████████████████████████████████████| 144/144 [00:00<00:00, 143976.11it/s]
# 100%|████████████████████████████████████| 166/166 [00:00<00:00, 163171.89it/s]
# 100%|████████████████████████████████████████████████| 164/164 [00:00<?, ?it/s]
# 100%|████████████████████████████████████| 219/219 [00:00<00:00, 219015.87it/s]
# 100%|████████████████████████████████████| 166/166 [00:00<00:00, 166091.24it/s]
# 100%|████████████████████████████████████| 151/151 [00:00<00:00, 151155.11it/s]
# 100%|████████████████████████████████████| 142/142 [00:00<00:00, 142078.05it/s]
# 100%|████████████████████████████████████| 304/304 [00:00<00:00, 304239.66it/s]
# 100%|████████████████████████████████████| 222/222 [00:00<00:00, 222175.02it/s]
# 100%|████████████████████████████████████| 222/222 [00:00<00:00, 111074.26it/s]
# 100%|████████████████████████████████████| 148/148 [00:00<00:00, 148152.03it/s]
# 100%|████████████████████████████████████| 164/164 [00:00<00:00, 164129.29it/s]
# 100%|████████████████████████████████████| 246/246 [00:00<00:00, 246076.50it/s]
# 100%|████████████████████████████████████| 246/246 [00:00<00:00, 246193.94it/s]
# 100%|████████████████████████████████████| 164/164 [00:00<00:00, 163777.58it/s]
# 100%|████████████████████████████████████| 164/164 [00:00<00:00, 164129.29it/s]
# 100%|████████████████████████████████████| 164/164 [00:00<00:00, 164090.14it/s]
# 100%|████████████████████████████████████| 328/328 [00:00<00:00, 328258.58it/s]
# 100%|████████████████████████████████████| 164/164 [00:00<00:00, 164090.14it/s]
# 100%|████████████████████████████████████████████████| 166/166 [00:00<?, ?it/s]
# 100%|████████████████████████████████████| 166/166 [00:00<00:00, 166130.87it/s]
# 100%|████████████████████████████████████████████████| 164/164 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████| 158/158 [00:00<?, ?it/s]
# 100%|████████████████████████████████████| 246/246 [00:00<00:00, 123052.93it/s]
# 100%|████████████████████████████████████████████████| 225/225 [00:00<?, ?it/s]
# 100%|████████████████████████████████████| 246/246 [00:00<00:00, 246135.21it/s]
# 100%|████████████████████████████████████| 160/160 [00:00<00:00, 160011.60it/s]
# 100%|████████████████████████████████████| 153/153 [00:00<00:00, 153157.16it/s]
# 100%|████████████████████████████████████| 127/127 [00:00<00:00, 127039.50it/s]
# 100%|████████████████████████████████████| 164/164 [00:00<00:00, 164246.86it/s]
# 100%|████████████████████████████████████| 166/166 [00:00<00:00, 166012.03it/s]
# 100%|████████████████████████████████████| 234/234 [00:00<00:00, 116994.53it/s]
# 100%|████████████████████████████████████| 102/102 [00:00<00:00, 102056.06it/s]
# 100%|████████████████████████████████████| 166/166 [00:00<00:00, 166091.24it/s]
# 100%|████████████████████████████████████████████████| 222/222 [00:00<?, ?it/s]
# 100%|████████████████████████████████████| 166/166 [00:00<00:00, 166130.87it/s]
# 100%|████████████████████████████████████████████████| 164/164 [00:00<?, ?it/s]
# 100%|████████████████████████████████████| 246/246 [00:00<00:00, 245959.19it/s]
# 100%|█████████████████████████████████████| 164/164 [00:00<00:00, 82005.94it/s]
# 100%|████████████████████████████████████| 150/150 [00:00<00:00, 150082.44it/s]
# 100%|████████████████████████████████████████████████| 151/151 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████| 150/150 [00:00<?, ?it/s]
# 100%|████████████████████████████████████| 150/150 [00:00<00:00, 150261.67it/s]

# %%
all_train.sample(frac=1, axis=1).sample(frac=1).reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-06655157baf1> in <module>
# ----> 1 all_train.sample(frac=1, axis=1).sample(frac=1).reset_index(drop=True)
#
# NameError: name 'all_train' is not defined

# %%
all_train = all_train.sample(frac=1, axis=1).sample(frac=1).reset_index(drop=True)
all_test = all_test.sample(frac=1, axis=1).sample(frac=1).reset_index(drop=True)

x_train = np.array(all_train["path"])
y_train = np.array(all_train["label_id"])
target_labels= np.array(all_train["label_name"])

x_test = np.array(all_test["path"])
y_test = np.array(all_test["label_id"])

# %%
#def load_dataset(path):
#    data = load_files(path)
#    files = np.array(data['filenames'])
#    print(files)
#    targets = np.array(data['target'])
#    print(targets)
#    target_labels = np.array(data['target_names'])
#    print(target_labels)
#    return files,targets,target_labels
    
#x_train, y_train,target_labels = load_dataset(DATADIR)
#x_test, y_test,_ = load_dataset(DATADIR_test)
#print('Loading complete!')

#print('Training set size : ' , x_train.shape[0])
#print('Testing set size : ', x_test.shape[0])

# %%
x_train
# Out:
# array(['../dataset/fruits-360/Training\\Potato Red\\120_100.jpg',
#        '../dataset/fruits-360/Training\\Apple Braeburn\\140_100.jpg',
#        '../dataset/fruits-360/Training\\Pepper Red\\r_280_100.jpg', ...,
#        '../dataset/fruits-360/Training\\Apple Red 3\\r_153_100.jpg',
#        '../dataset/fruits-360/Training\\Tomato 3\\r_101_100.jpg',
#        '../dataset/fruits-360/Training\\Tomato Yellow\\162_100.jpg'],
#       dtype=object)

# %%
target_labels
# Out:
# array(['Potato', 'Apple', 'Pepper', ..., 'Apple', 'Tomato', 'Tomato'],
#       dtype=object)

# %%
y_train
# Out:
# array([7, 0, 3, ..., 0, 6, 6], dtype=int64)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)

y_train
# Out:
# (27908,)
# (27908,)
# (9335,)
# (9335,)
# array([7, 0, 3, ..., 0, 6, 6], dtype=int64)

# %%
from keras.utils import np_utils
no_of_classes = len(np.unique(y_train))
y_train = np_utils.to_categorical(y_train,no_of_classes)
y_test = np_utils.to_categorical(y_test,no_of_classes)
y_train[0]
print(no_of_classes)
# Out:
# Using TensorFlow backend.
# 10

# %%
# Now, we have to divide the validation set into test and validation set
x_test,x_valid = x_test[7000:],x_test[:7000]
y_test,y_vaild = y_test[7000:],y_test[:7000]
print('Vaildation X : ',x_valid.shape)
print('Vaildation y :',y_vaild.shape)
print('Test X : ',x_test.shape)
print('Test y : ',y_test.shape)
# Out:
# Vaildation X :  (7000,)
# Vaildation y : (7000, 10)
# Test X :  (2335,)
# Test y :  (2335, 10)

# %%
from keras.preprocessing.image import array_to_img, img_to_array, load_img

def convert_image_to_array(files):
    images_as_array=[]
    for file in files:
        # Convert to Numpy Array
        images_as_array.append(img_to_array(load_img(file,target_size=(32, 32))))
    return images_as_array

x_train = np.array(convert_image_to_array(x_train))
print('Training set shape : ',x_train.shape)

x_valid = np.array(convert_image_to_array(x_valid))
print('Validation set shape : ',x_valid.shape)

x_test = np.array(convert_image_to_array(x_test))
print('Test set shape : ',x_test.shape)

print('1st training image shape ',x_train[0].shape)
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-581d4d968d0e> in <module>
#       8     return images_as_array
#       9
# ---> 10 x_train = np.array(convert_image_to_array(x_train))
#      11 print('Training set shape : ',x_train.shape)
#      12
#
# NameError: name 'np' is not defined

# %%
x_train = x_train.astype('float32')/255
x_valid = x_valid.astype('float32')/255
x_test = x_test.astype('float32')/255

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize =(30,5))
for i in range(10):
    ax = fig.add_subplot(2,5,i+1,xticks=[],yticks=[])
    ax.imshow(np.squeeze(x_train[i]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e2f77307000f> in <module>
#       4 for i in range(10):
#       5     ax = fig.add_subplot(2,5,i+1,xticks=[],yticks=[])
# ----> 6     ax.imshow(np.squeeze(x_train[i]))
#
# NameError: name 'np' is not defined

# %%
#Simple CNN from scratch - we are using 3 Conv layers followed by maxpooling layers.
# At the end we add dropout, flatten and some fully connected layers(Dense).

from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D
from keras.layers import Activation, Dense, Flatten, Dropout
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from keras import backend as K

model = Sequential()
model.add(Conv2D(filters = 16, kernel_size = 2,input_shape=(32,32,3),padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters = 32,kernel_size = 2,activation= 'relu',padding='same'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters = 64,kernel_size = 2,activation= 'relu',padding='same'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters = 128,kernel_size = 2,activation= 'relu',padding='same'))
model.add(MaxPooling2D(pool_size=2))

model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(150))
model.add(Activation('relu'))
model.add(Dropout(0.4))
model.add(Dense(10,activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 16)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 128)         32896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 150)               76950
# _________________________________________________________________
# activation_2 (Activation)    (None, 150)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 150)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1510
# =================================================================
# Total params: 121,900
# Trainable params: 121,900
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])
print('Compiled!')
# Out:
# Compiled!

# %%
history = model.fit(x_train,y_train,
        batch_size = 32,
        epochs=10,
        validation_data=(x_valid, y_vaild),
        verbose=2, 
     #   shuffle=True
                   )
# Out:
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
#  - 14s - loss: 0.7360 - accuracy: 0.7439 - val_loss: 0.2250 - val_accuracy: 0.9191
# Epoch 2/10
#  - 14s - loss: 0.1088 - accuracy: 0.9638 - val_loss: 0.0432 - val_accuracy: 0.9839
# Epoch 3/10
#  - 15s - loss: 0.0478 - accuracy: 0.9836 - val_loss: 0.0615 - val_accuracy: 0.9730
# Epoch 4/10
#  - 14s - loss: 0.0332 - accuracy: 0.9890 - val_loss: 0.0948 - val_accuracy: 0.9740
# Epoch 5/10
#  - 15s - loss: 0.0222 - accuracy: 0.9927 - val_loss: 0.0873 - val_accuracy: 0.9707
# Epoch 6/10
#  - 14s - loss: 0.0176 - accuracy: 0.9944 - val_loss: 0.0296 - val_accuracy: 0.9906
# Epoch 7/10
#  - 12s - loss: 0.0196 - accuracy: 0.9939 - val_loss: 0.0511 - val_accuracy: 0.9881
# Epoch 8/10
#  - 12s - loss: 0.0143 - accuracy: 0.9954 - val_loss: 0.0276 - val_accuracy: 0.9913
# Epoch 9/10
#  - 12s - loss: 0.0147 - accuracy: 0.9958 - val_loss: 0.0435 - val_accuracy: 0.9879
# Epoch 10/10
#  - 13s - loss: 0.0144 - accuracy: 0.9964 - val_loss: 0.0669 - val_accuracy: 0.9823

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.980728030204773

# %%
y_pred = model.predict(x_test)

# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(16, 9))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=16, replace=False)):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_pred[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(TYPES[pred_idx], TYPES[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))

# %%
#Finally lets visualize the loss and accuracy wrt epochs

import matplotlib.pyplot as plt 
plt.figure(1)  
   
 # summarize history for accuracy  
   
plt.subplot(211)  
plt.plot(history.history['accuracy'])  
plt.plot(history.history['val_accuracy'])  
plt.title('model accuracy')  
plt.ylabel('accuracy')  
plt.xlabel('epoch')  
plt.legend(['train', 'test'], loc='upper left')  
   
 # summarize history for loss  
   
plt.subplot(212)  
plt.plot(history.history['loss'])  
plt.plot(history.history['val_loss'])  
plt.title('model loss')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
plt.legend(['train', 'test'], loc='upper left')  
plt.show()

# %%
model = Sequential()
model.add(Conv2D(filters = 16, kernel_size = 2,input_shape=(32,32,3),padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters = 32,kernel_size = 2,activation= 'relu',padding='same'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters = 64,kernel_size = 2,activation= 'relu',padding='same'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters = 128,kernel_size = 2,activation= 'relu',padding='same'))
model.add(MaxPooling2D(pool_size=2))

model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(150))
model.add(Activation('relu'))
model.add(Dropout(0.4))
model.add(Dense(10,activation = 'softmax'))
model.summary()



model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])
print('Compiled!')

history = model.fit(x_train,y_train,
        batch_size = 32,
        epochs=10,
        validation_data=(x_valid, y_vaild),
        verbose=2, 
        callbacks=[tensorboard]
        )

# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])

# %%
from datetime import datetime
from keras.callbacks import TensorBoard

from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D
from keras.layers import Activation, Dense, Flatten, Dropout
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from keras import backend as K
dense_layers = [0, 1, 2]
layer_sizes = [32, 64, 128]
conv_layers = [1, 2, 3]

for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME = "Fruits-{}-conv-{}-nodes-{}-dense-{}".format(conv_layer, layer_size, dense_layer, datetime.now().strftime("%d%m%Y-%H%M%S"))
            print(NAME)

            model = Sequential()

            model.add(Conv2D(layer_size, 2, input_shape=(32,32,3),padding='same'))
            model.add(Activation('relu'))
            model.add(MaxPooling2D(pool_size=2))

            for l in range(conv_layer-1):
                model.add(Conv2D(layer_size, 2))
                model.add(Activation('relu'))
                model.add(MaxPooling2D(pool_size=2))

            model.add(Flatten())

            for _ in range(dense_layer):
                model.add(Dense(layer_size))
                model.add(Activation('relu'))

            model.add(Dense(10,activation = 'softmax'))
    

            tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))
            #
            #!
            #categorical_crossentropy
            #!
            #
            model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])
            print('Compiled!')
            
            history = model.fit(x_train,y_train,
        batch_size = 32,
        epochs=10,
        validation_data=(x_valid, y_vaild),
        verbose=2, 
        callbacks=[tensorboard]
        )

# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
# Fruits-1-conv-32-nodes-0-dense-31052020-105703
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
# E:\ProgramData\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.108056). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
#  - 12s - loss: 0.3622 - accuracy: 0.8969 - val_loss: 0.2539 - val_accuracy: 0.9120
# Epoch 2/10
#  - 11s - loss: 0.0387 - accuracy: 0.9909 - val_loss: 0.1794 - val_accuracy: 0.9479
# Epoch 3/10
#  - 12s - loss: 0.0130 - accuracy: 0.9967 - val_loss: 0.1489 - val_accuracy: 0.9530
# Epoch 4/10
#  - 12s - loss: 0.0052 - accuracy: 0.9987 - val_loss: 0.4072 - val_accuracy: 0.8920
# Epoch 5/10
#  - 10s - loss: 0.0029 - accuracy: 0.9994 - val_loss: 0.1297 - val_accuracy: 0.9657
# Epoch 6/10
#  - 10s - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.1401 - val_accuracy: 0.9637
# Epoch 7/10
#  - 10s - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1841 - val_accuracy: 0.9520
# Epoch 8/10
#  - 10s - loss: 7.3687e-04 - accuracy: 0.9998 - val_loss: 0.1346 - val_accuracy: 0.9683
# Epoch 9/10
#  - 10s - loss: 4.5836e-04 - accuracy: 0.9999 - val_loss: 0.1582 - val_accuracy: 0.9671
# Epoch 10/10
#  - 9s - loss: 2.8977e-04 - accuracy: 1.0000 - val_loss: 0.1300 - val_accuracy: 0.9734
# Fruits-2-conv-32-nodes-0-dense-31052020-105850
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
#  - 12s - loss: 0.5244 - accuracy: 0.8352 - val_loss: 1.0263 - val_accuracy: 0.6639
# Epoch 2/10
#  - 12s - loss: 0.0663 - accuracy: 0.9820 - val_loss: 0.2262 - val_accuracy: 0.9149
# Epoch 3/10
#  - 12s - loss: 0.0234 - accuracy: 0.9931 - val_loss: 0.1112 - val_accuracy: 0.9624
# Epoch 4/10
#  - 12s - loss: 0.0098 - accuracy: 0.9971 - val_loss: 0.1324 - val_accuracy: 0.9551
# Epoch 5/10
#  - 12s - loss: 0.0055 - accuracy: 0.9985 - val_loss: 0.1143 - val_accuracy: 0.9601
# Epoch 6/10
#  - 12s - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.1079 - val_accuracy: 0.9677
# Epoch 7/10
#  - 13s - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.0944 - val_accuracy: 0.9701
# Epoch 8/10
#  - 12s - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.1468 - val_accuracy: 0.9689
# Epoch 9/10
#  - 13s - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.1121 - val_accuracy: 0.9713
# Epoch 10/10
#  - 13s - loss: 8.3756e-04 - accuracy: 0.9997 - val_loss: 0.1050 - val_accuracy: 0.9759
# Fruits-3-conv-32-nodes-0-dense-31052020-110055
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
#  - 14s - loss: 0.7169 - accuracy: 0.7626 - val_loss: 0.4686 - val_accuracy: 0.8183
# Epoch 2/10
#  - 13s - loss: 0.1163 - accuracy: 0.9637 - val_loss: 0.1416 - val_accuracy: 0.9494
# Epoch 3/10
#  - 13s - loss: 0.0448 - accuracy: 0.9867 - val_loss: 0.1373 - val_accuracy: 0.9584
# Epoch 4/10
#  - 13s - loss: 0.0231 - accuracy: 0.9929 - val_loss: 0.0869 - val_accuracy: 0.9743
# Epoch 5/10
#  - 13s - loss: 0.0132 - accuracy: 0.9960 - val_loss: 0.1947 - val_accuracy: 0.9401
# Epoch 6/10
#  - 13s - loss: 0.0088 - accuracy: 0.9970 - val_loss: 0.0791 - val_accuracy: 0.9806
# Epoch 7/10
#  - 13s - loss: 0.0066 - accuracy: 0.9981 - val_loss: 0.1145 - val_accuracy: 0.9709
# Epoch 8/10
#  - 14s - loss: 0.0053 - accuracy: 0.9982 - val_loss: 0.1224 - val_accuracy: 0.9791
# Epoch 9/10
#  - 17s - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.1146 - val_accuracy: 0.9787
# Epoch 10/10
#  - 17s - loss: 0.0032 - accuracy: 0.9988 - val_loss: 0.1127 - val_accuracy: 0.9806
# Fruits-1-conv-64-nodes-0-dense-31052020-110317
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
#  - 18s - loss: 0.3312 - accuracy: 0.9016 - val_loss: 0.2369 - val_accuracy: 0.9274
# Epoch 2/10
#  - 18s - loss: 0.0222 - accuracy: 0.9944 - val_loss: 0.1178 - val_accuracy: 0.9627
# Epoch 3/10
#  - 17s - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.1405 - val_accuracy: 0.9601
# Epoch 4/10
#  - 19s - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.1529 - val_accuracy: 0.9649
# Epoch 5/10
#  - 20s - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.1362 - val_accuracy: 0.9731
# Epoch 6/10
#  - 18s - loss: 7.4237e-04 - accuracy: 0.9999 - val_loss: 0.1186 - val_accuracy: 0.9707
# Epoch 7/10
#  - 18s - loss: 5.8048e-04 - accuracy: 0.9998 - val_loss: 0.1061 - val_accuracy: 0.9773
# Epoch 8/10
#  - 18s - loss: 3.3313e-04 - accuracy: 1.0000 - val_loss: 0.1436 - val_accuracy: 0.9754
# Epoch 9/10
#  - 19s - loss: 2.7763e-04 - accuracy: 0.9999 - val_loss: 0.1438 - val_accuracy: 0.9701
# Epoch 10/10
#  - 18s - loss: 1.6268e-04 - accuracy: 1.0000 - val_loss: 0.1103 - val_accuracy: 0.9787
# Fruits-2-conv-64-nodes-0-dense-31052020-110620
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
# E:\ProgramData\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.124421). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
#  - 27s - loss: 0.4011 - accuracy: 0.8739 - val_loss: 0.1576 - val_accuracy: 0.9354
# Epoch 2/10
#  - 27s - loss: 0.0325 - accuracy: 0.9908 - val_loss: 0.1214 - val_accuracy: 0.9647
# Epoch 3/10
#  - 28s - loss: 0.0099 - accuracy: 0.9966 - val_loss: 0.3356 - val_accuracy: 0.8999
# Epoch 4/10
#  - 29s - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.0994 - val_accuracy: 0.9761
# Epoch 5/10
#  - 27s - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.0815 - val_accuracy: 0.9839
# Epoch 6/10
#  - 24s - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.1490 - val_accuracy: 0.9726
# Epoch 7/10
#  - 23s - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.1132 - val_accuracy: 0.9794
# Epoch 8/10
#  - 23s - loss: 9.1920e-04 - accuracy: 0.9997 - val_loss: 0.0930 - val_accuracy: 0.9833
# Epoch 9/10
#  - 23s - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.1259 - val_accuracy: 0.9789
# Epoch 10/10
#  - 23s - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.2623 - val_accuracy: 0.9504
# Fruits-3-conv-64-nodes-0-dense-31052020-111035
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
#  - 25s - loss: 0.5474 - accuracy: 0.8187 - val_loss: 0.1939 - val_accuracy: 0.9279
# Epoch 2/10
#  - 25s - loss: 0.0556 - accuracy: 0.9823 - val_loss: 0.1659 - val_accuracy: 0.9280
# Epoch 3/10
#  - 25s - loss: 0.0211 - accuracy: 0.9936 - val_loss: 0.1611 - val_accuracy: 0.9540
# Epoch 4/10
#  - 25s - loss: 0.0105 - accuracy: 0.9969 - val_loss: 0.0772 - val_accuracy: 0.9829
# Epoch 5/10
#  - 25s - loss: 0.0056 - accuracy: 0.9982 - val_loss: 0.0875 - val_accuracy: 0.9796
# Epoch 6/10
#  - 25s - loss: 0.0047 - accuracy: 0.9984 - val_loss: 0.0706 - val_accuracy: 0.9853
# Epoch 7/10
#  - 25s - loss: 0.0040 - accuracy: 0.9990 - val_loss: 0.0783 - val_accuracy: 0.9870
# Epoch 8/10
#  - 27s - loss: 0.0040 - accuracy: 0.9992 - val_loss: 0.1052 - val_accuracy: 0.9859
# Epoch 9/10
#  - 27s - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.0795 - val_accuracy: 0.9857
# Epoch 10/10
#  - 26s - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0999 - val_accuracy: 0.9870
# Fruits-1-conv-128-nodes-0-dense-31052020-111451
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
#  - 31s - loss: 0.2773 - accuracy: 0.9151 - val_loss: 0.1746 - val_accuracy: 0.9397
# Epoch 2/10
#  - 31s - loss: 0.0153 - accuracy: 0.9956 - val_loss: 0.0957 - val_accuracy: 0.9686
# Epoch 3/10
#  - 31s - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.1190 - val_accuracy: 0.9670
# Epoch 4/10
#  - 31s - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.1007 - val_accuracy: 0.9771
# Epoch 5/10
#  - 30s - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.2016 - val_accuracy: 0.9513
# Epoch 6/10
#  - 30s - loss: 8.1643e-04 - accuracy: 0.9997 - val_loss: 0.1404 - val_accuracy: 0.9680
# Epoch 7/10
#  - 31s - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.1338 - val_accuracy: 0.9714
# Epoch 8/10
#  - 31s - loss: 4.1107e-04 - accuracy: 0.9998 - val_loss: 0.1243 - val_accuracy: 0.9776
# Epoch 9/10
#  - 31s - loss: 6.6441e-04 - accuracy: 0.9999 - val_loss: 0.1309 - val_accuracy: 0.9756
# Epoch 10/10
#  - 30s - loss: 4.8120e-04 - accuracy: 0.9997 - val_loss: 0.1500 - val_accuracy: 0.9746
# Fruits-2-conv-128-nodes-0-dense-31052020-111957
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
#  - 51s - loss: 0.3019 - accuracy: 0.9029 - val_loss: 0.0978 - val_accuracy: 0.9679
# Epoch 2/10
#  - 48s - loss: 0.0156 - accuracy: 0.9951 - val_loss: 0.0742 - val_accuracy: 0.9764
# Epoch 3/10
#  - 51s - loss: 0.0053 - accuracy: 0.9986 - val_loss: 0.0518 - val_accuracy: 0.9861
# Epoch 4/10
#  - 53s - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.0472 - val_accuracy: 0.9901
# Epoch 5/10
#  - 48s - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.1380 - val_accuracy: 0.9777
# Epoch 6/10
#  - 49s - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0622 - val_accuracy: 0.9893
# Epoch 7/10
#  - 47s - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0744 - val_accuracy: 0.9876
# Epoch 8/10
#  - 47s - loss: 0.0010 - accuracy: 0.9999 - val_loss: 0.0865 - val_accuracy: 0.9879
# Epoch 9/10
#  - 47s - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0950 - val_accuracy: 0.9889
# Epoch 10/10
#  - 47s - loss: 6.0553e-04 - accuracy: 0.9999 - val_loss: 0.2153 - val_accuracy: 0.9790
# Fruits-3-conv-128-nodes-0-dense-31052020-112806
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
#  - 52s - loss: 0.3483 - accuracy: 0.8823 - val_loss: 0.1276 - val_accuracy: 0.9553
# Epoch 2/10
#  - 51s - loss: 0.0249 - accuracy: 0.9927 - val_loss: 0.0649 - val_accuracy: 0.9841
# Epoch 3/10
#  - 51s - loss: 0.0104 - accuracy: 0.9970 - val_loss: 0.0728 - val_accuracy: 0.9793
# Epoch 4/10
#  - 52s - loss: 0.0110 - accuracy: 0.9976 - val_loss: 0.1206 - val_accuracy: 0.9767
# Epoch 5/10
#  - 57s - loss: 0.0070 - accuracy: 0.9982 - val_loss: 0.0502 - val_accuracy: 0.9861
# Epoch 6/10
#  - 66s - loss: 0.0063 - accuracy: 0.9982 - val_loss: 0.1051 - val_accuracy: 0.9839
# Epoch 7/10
#  - 92s - loss: 0.0046 - accuracy: 0.9992 - val_loss: 0.1207 - val_accuracy: 0.9804
# Epoch 8/10
#  - 55s - loss: 0.0052 - accuracy: 0.9989 - val_loss: 0.0578 - val_accuracy: 0.9887
# Epoch 9/10
#  - 59s - loss: 0.0047 - accuracy: 0.9988 - val_loss: 0.1101 - val_accuracy: 0.9879
# Epoch 10/10
#  - 56s - loss: 0.0037 - accuracy: 0.9993 - val_loss: 0.1847 - val_accuracy: 0.9819
# Fruits-1-conv-32-nodes-1-dense-31052020-113756
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
# E:\ProgramData\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.121461). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
#  - 12s - loss: 0.9358 - accuracy: 0.7002 - val_loss: 0.6364 - val_accuracy: 0.7860
# Epoch 2/10
#  - 12s - loss: 0.2173 - accuracy: 0.9397 - val_loss: 0.3598 - val_accuracy: 0.8974
# Epoch 3/10
#  - 12s - loss: 0.0653 - accuracy: 0.9805 - val_loss: 0.2221 - val_accuracy: 0.9314
# Epoch 4/10
#  - 11s - loss: 0.0177 - accuracy: 0.9962 - val_loss: 0.1502 - val_accuracy: 0.9557
# Epoch 5/10
#  - 11s - loss: 0.0061 - accuracy: 0.9985 - val_loss: 0.1221 - val_accuracy: 0.9660
# Epoch 6/10
#  - 12s - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.0919 - val_accuracy: 0.9756
# Epoch 7/10
#  - 11s - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0819 - val_accuracy: 0.9804
# Epoch 8/10
#  - 11s - loss: 9.9712e-04 - accuracy: 0.9997 - val_loss: 0.1652 - val_accuracy: 0.9580
# Epoch 9/10
#  - 11s - loss: 9.4171e-04 - accuracy: 0.9997 - val_loss: 0.1150 - val_accuracy: 0.9814
# Epoch 10/10
#  - 11s - loss: 2.9304e-04 - accuracy: 0.9999 - val_loss: 0.1001 - val_accuracy: 0.9813
# Fruits-2-conv-32-nodes-1-dense-31052020-113954
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
#  - 14s - loss: 0.5011 - accuracy: 0.8437 - val_loss: 0.2394 - val_accuracy: 0.9136
# Epoch 2/10
#  - 13s - loss: 0.0522 - accuracy: 0.9845 - val_loss: 0.1380 - val_accuracy: 0.9473
# Epoch 3/10
#  - 13s - loss: 0.0162 - accuracy: 0.9955 - val_loss: 0.1194 - val_accuracy: 0.9649
# Epoch 4/10
#  - 13s - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.0821 - val_accuracy: 0.9749
# Epoch 5/10
#  - 13s - loss: 0.0043 - accuracy: 0.9984 - val_loss: 0.0973 - val_accuracy: 0.9787
# Epoch 6/10
#  - 13s - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.1051 - val_accuracy: 0.9729
# Epoch 7/10
#  - 13s - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.1208 - val_accuracy: 0.9751
# Epoch 8/10
#  - 13s - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.1262 - val_accuracy: 0.9753
# Epoch 9/10
#  - 12s - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0878 - val_accuracy: 0.9821
# Epoch 10/10
#  - 12s - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.1878 - val_accuracy: 0.9576
# Fruits-3-conv-32-nodes-1-dense-31052020-114204
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
#  - 14s - loss: 0.7531 - accuracy: 0.7476 - val_loss: 0.3398 - val_accuracy: 0.8901
# Epoch 2/10
#  - 13s - loss: 0.1162 - accuracy: 0.9646 - val_loss: 0.1320 - val_accuracy: 0.9530
# Epoch 3/10
#  - 13s - loss: 0.0421 - accuracy: 0.9874 - val_loss: 0.0949 - val_accuracy: 0.9697
# Epoch 4/10
#  - 13s - loss: 0.0221 - accuracy: 0.9936 - val_loss: 0.1320 - val_accuracy: 0.9689
# Epoch 5/10
#  - 13s - loss: 0.0150 - accuracy: 0.9958 - val_loss: 0.0896 - val_accuracy: 0.9766
# Epoch 6/10
#  - 13s - loss: 0.0120 - accuracy: 0.9968 - val_loss: 0.0966 - val_accuracy: 0.9803
# Epoch 7/10
#  - 13s - loss: 0.0079 - accuracy: 0.9977 - val_loss: 0.1273 - val_accuracy: 0.9727
# Epoch 8/10
#  - 13s - loss: 0.0070 - accuracy: 0.9978 - val_loss: 0.0829 - val_accuracy: 0.9793
# Epoch 9/10
#  - 13s - loss: 0.0065 - accuracy: 0.9982 - val_loss: 0.0782 - val_accuracy: 0.9839
# Epoch 10/10
#  - 13s - loss: 0.0044 - accuracy: 0.9989 - val_loss: 0.1561 - val_accuracy: 0.9649
# Fruits-1-conv-64-nodes-1-dense-31052020-114417
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
#  - 24s - loss: 0.5285 - accuracy: 0.8451 - val_loss: 0.4210 - val_accuracy: 0.8441
# Epoch 2/10
#  - 24s - loss: 0.0449 - accuracy: 0.9879 - val_loss: 0.1534 - val_accuracy: 0.9443
# Epoch 3/10
#  - 23s - loss: 0.0126 - accuracy: 0.9968 - val_loss: 0.1420 - val_accuracy: 0.9526
# Epoch 4/10
#  - 23s - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.1219 - val_accuracy: 0.9696
# Epoch 5/10
#  - 24s - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.2888 - val_accuracy: 0.9314
# Epoch 6/10
#  - 23s - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.1367 - val_accuracy: 0.9666
# Epoch 7/10
#  - 24s - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.1270 - val_accuracy: 0.9687
# Epoch 8/10
#  - 24s - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0886 - val_accuracy: 0.9771
# Epoch 9/10
#  - 24s - loss: 7.5089e-04 - accuracy: 0.9997 - val_loss: 0.1036 - val_accuracy: 0.9790
# Epoch 10/10
#  - 24s - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.1094 - val_accuracy: 0.9769
# Fruits-2-conv-64-nodes-1-dense-31052020-114815
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
#  - 26s - loss: 0.3240 - accuracy: 0.8942 - val_loss: 0.1291 - val_accuracy: 0.9567
# Epoch 2/10
#  - 25s - loss: 0.0183 - accuracy: 0.9947 - val_loss: 0.0665 - val_accuracy: 0.9796
# Epoch 3/10
#  - 28s - loss: 0.0061 - accuracy: 0.9978 - val_loss: 0.0901 - val_accuracy: 0.9819
# Epoch 4/10
#  - 25s - loss: 0.0062 - accuracy: 0.9984 - val_loss: 0.0801 - val_accuracy: 0.9844
# Epoch 5/10
#  - 24s - loss: 0.0046 - accuracy: 0.9993 - val_loss: 0.0783 - val_accuracy: 0.9816
# Epoch 6/10
#  - 25s - loss: 0.0035 - accuracy: 0.9994 - val_loss: 0.0754 - val_accuracy: 0.9883
# Epoch 7/10
#  - 28s - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.1238 - val_accuracy: 0.9843
# Epoch 8/10
#  - 28s - loss: 9.4110e-04 - accuracy: 0.9998 - val_loss: 0.1086 - val_accuracy: 0.9879
# Epoch 9/10
#  - 26s - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.1057 - val_accuracy: 0.9863
# Epoch 10/10
#  - 25s - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.1937 - val_accuracy: 0.9716
# Fruits-3-conv-64-nodes-1-dense-31052020-115236
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
#  - 27s - loss: 0.4476 - accuracy: 0.8521 - val_loss: 0.1577 - val_accuracy: 0.9417
# Epoch 2/10
#  - 26s - loss: 0.0328 - accuracy: 0.9899 - val_loss: 0.0819 - val_accuracy: 0.9847
# Epoch 3/10
#  - 26s - loss: 0.0184 - accuracy: 0.9952 - val_loss: 0.0680 - val_accuracy: 0.9870
# Epoch 4/10
#  - 26s - loss: 0.0086 - accuracy: 0.9979 - val_loss: 0.0815 - val_accuracy: 0.9881
# Epoch 5/10
#  - 26s - loss: 0.0058 - accuracy: 0.9986 - val_loss: 0.1562 - val_accuracy: 0.9747
# Epoch 6/10
#  - 26s - loss: 0.0070 - accuracy: 0.9985 - val_loss: 0.0765 - val_accuracy: 0.9860
# Epoch 7/10
#  - 26s - loss: 0.0049 - accuracy: 0.9991 - val_loss: 0.0894 - val_accuracy: 0.9859
# Epoch 8/10
#  - 26s - loss: 0.0085 - accuracy: 0.9989 - val_loss: 0.0688 - val_accuracy: 0.9910
# Epoch 9/10
#  - 26s - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.0738 - val_accuracy: 0.9934
# Epoch 10/10
#  - 26s - loss: 0.0036 - accuracy: 0.9990 - val_loss: 0.0407 - val_accuracy: 0.9899
# Fruits-1-conv-128-nodes-1-dense-31052020-115656
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
#  - 64s - loss: 0.2867 - accuracy: 0.9141 - val_loss: 0.4564 - val_accuracy: 0.8606
# Epoch 2/10
#  - 66s - loss: 0.0109 - accuracy: 0.9967 - val_loss: 0.0793 - val_accuracy: 0.9743
# Epoch 3/10
#  - 67s - loss: 0.0047 - accuracy: 0.9987 - val_loss: 0.0702 - val_accuracy: 0.9843
# Epoch 4/10
#  - 67s - loss: 0.0044 - accuracy: 0.9990 - val_loss: 0.0615 - val_accuracy: 0.9870
# Epoch 5/10
#  - 66s - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.0875 - val_accuracy: 0.9824
# Epoch 6/10
#  - 65s - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.1230 - val_accuracy: 0.9769
# Epoch 7/10
#  - 64s - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.1557 - val_accuracy: 0.9747
# Epoch 8/10
#  - 65s - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.0696 - val_accuracy: 0.9879
# Epoch 9/10
#  - 65s - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0945 - val_accuracy: 0.9837
# Epoch 10/10
#  - 66s - loss: 8.0538e-05 - accuracy: 1.0000 - val_loss: 0.1051 - val_accuracy: 0.9874
# Fruits-2-conv-128-nodes-1-dense-31052020-120750
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
#  - 57s - loss: 0.2324 - accuracy: 0.9245 - val_loss: 0.0713 - val_accuracy: 0.9850
# Epoch 2/10
#  - 56s - loss: 0.0172 - accuracy: 0.9960 - val_loss: 0.0634 - val_accuracy: 0.9854
# Epoch 3/10
#  - 56s - loss: 0.0086 - accuracy: 0.9980 - val_loss: 0.0479 - val_accuracy: 0.9893
# Epoch 4/10
#  - 57s - loss: 0.0032 - accuracy: 0.9992 - val_loss: 0.0590 - val_accuracy: 0.9871
# Epoch 5/10
#  - 57s - loss: 0.0043 - accuracy: 0.9991 - val_loss: 0.0779 - val_accuracy: 0.9889
# Epoch 6/10
#  - 56s - loss: 0.0074 - accuracy: 0.9990 - val_loss: 0.0886 - val_accuracy: 0.9907
# Epoch 7/10
#  - 57s - loss: 0.0034 - accuracy: 0.9994 - val_loss: 0.1293 - val_accuracy: 0.9787
# Epoch 8/10
#  - 56s - loss: 0.0035 - accuracy: 0.9994 - val_loss: 0.7352 - val_accuracy: 0.9451
# Epoch 9/10
#  - 53s - loss: 0.0035 - accuracy: 0.9994 - val_loss: 0.0826 - val_accuracy: 0.9891
# Epoch 10/10
#  - 53s - loss: 0.0024 - accuracy: 0.9996 - val_loss: 0.0943 - val_accuracy: 0.9883
# Fruits-3-conv-128-nodes-1-dense-31052020-121710
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
#  - 52s - loss: 0.3462 - accuracy: 0.8834 - val_loss: 0.0911 - val_accuracy: 0.9750
# Epoch 2/10
#  - 51s - loss: 0.0306 - accuracy: 0.9925 - val_loss: 0.0476 - val_accuracy: 0.9839
# Epoch 3/10
#  - 52s - loss: 0.0164 - accuracy: 0.9961 - val_loss: 0.0766 - val_accuracy: 0.9801
# Epoch 4/10
#  - 54s - loss: 0.0129 - accuracy: 0.9967 - val_loss: 0.0385 - val_accuracy: 0.9906
# Epoch 5/10
#  - 53s - loss: 0.0123 - accuracy: 0.9976 - val_loss: 0.0643 - val_accuracy: 0.9887
# Epoch 6/10
#  - 54s - loss: 0.0114 - accuracy: 0.9983 - val_loss: 0.0326 - val_accuracy: 0.9941
# Epoch 7/10
#  - 52s - loss: 0.0118 - accuracy: 0.9982 - val_loss: 0.0901 - val_accuracy: 0.9827
# Epoch 8/10
#  - 54s - loss: 0.0090 - accuracy: 0.9988 - val_loss: 0.1038 - val_accuracy: 0.9823
# Epoch 9/10
#  - 53s - loss: 0.0053 - accuracy: 0.9993 - val_loss: 0.1058 - val_accuracy: 0.9863
# Epoch 10/10
#  - 52s - loss: 0.0045 - accuracy: 0.9995 - val_loss: 0.1149 - val_accuracy: 0.9870
# Fruits-1-conv-32-nodes-2-dense-31052020-122559
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
#  - 12s - loss: 0.6499 - accuracy: 0.7907 - val_loss: 0.3535 - val_accuracy: 0.8706
# Epoch 2/10
#  - 11s - loss: 0.0844 - accuracy: 0.9769 - val_loss: 0.1450 - val_accuracy: 0.9487
# Epoch 3/10
#  - 11s - loss: 0.0242 - accuracy: 0.9935 - val_loss: 0.1211 - val_accuracy: 0.9566
# Epoch 4/10
#  - 11s - loss: 0.0110 - accuracy: 0.9969 - val_loss: 0.1049 - val_accuracy: 0.9659
# Epoch 5/10
#  - 11s - loss: 0.0053 - accuracy: 0.9986 - val_loss: 0.1100 - val_accuracy: 0.9689
# Epoch 6/10
#  - 11s - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.0972 - val_accuracy: 0.9734
# Epoch 7/10
#  - 11s - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.1013 - val_accuracy: 0.9703
# Epoch 8/10
#  - 11s - loss: 0.0026 - accuracy: 0.9991 - val_loss: 0.1111 - val_accuracy: 0.9777
# Epoch 9/10
#  - 11s - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.1421 - val_accuracy: 0.9707
# Epoch 10/10
#  - 11s - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.1226 - val_accuracy: 0.9719
# Fruits-2-conv-32-nodes-2-dense-31052020-122752
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
#  - 13s - loss: 0.5577 - accuracy: 0.8174 - val_loss: 0.2009 - val_accuracy: 0.9284
# Epoch 2/10
#  - 12s - loss: 0.0400 - accuracy: 0.9882 - val_loss: 0.1008 - val_accuracy: 0.9616
# Epoch 3/10
#  - 12s - loss: 0.0133 - accuracy: 0.9962 - val_loss: 0.0742 - val_accuracy: 0.9806
# Epoch 4/10
#  - 12s - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.0504 - val_accuracy: 0.9813
# Epoch 5/10
#  - 12s - loss: 0.0071 - accuracy: 0.9982 - val_loss: 0.0621 - val_accuracy: 0.9880
# Epoch 6/10
#  - 12s - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.0699 - val_accuracy: 0.9800
# Epoch 7/10
#  - 12s - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.1233 - val_accuracy: 0.9740
# Epoch 8/10
#  - 12s - loss: 0.0046 - accuracy: 0.9989 - val_loss: 0.0358 - val_accuracy: 0.9943
# Epoch 9/10
#  - 12s - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.1783 - val_accuracy: 0.9674
# Epoch 10/10
#  - 12s - loss: 0.0024 - accuracy: 0.9997 - val_loss: 0.1094 - val_accuracy: 0.9873
# Fruits-3-conv-32-nodes-2-dense-31052020-122957
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
#  - 14s - loss: 0.7882 - accuracy: 0.7276 - val_loss: 0.9718 - val_accuracy: 0.6321
# Epoch 2/10
#  - 13s - loss: 0.1134 - accuracy: 0.9633 - val_loss: 0.4454 - val_accuracy: 0.8641
# Epoch 3/10
#  - 13s - loss: 0.0416 - accuracy: 0.9861 - val_loss: 0.0693 - val_accuracy: 0.9797
# Epoch 4/10
#  - 13s - loss: 0.0242 - accuracy: 0.9928 - val_loss: 0.0977 - val_accuracy: 0.9787
# Epoch 5/10
#  - 13s - loss: 0.0140 - accuracy: 0.9960 - val_loss: 0.0631 - val_accuracy: 0.9833
# Epoch 6/10
#  - 13s - loss: 0.0109 - accuracy: 0.9965 - val_loss: 0.0872 - val_accuracy: 0.9837
# Epoch 7/10
#  - 13s - loss: 0.0102 - accuracy: 0.9976 - val_loss: 0.1523 - val_accuracy: 0.9594
# Epoch 8/10
#  - 13s - loss: 0.0084 - accuracy: 0.9977 - val_loss: 0.0929 - val_accuracy: 0.9797
# Epoch 9/10
#  - 13s - loss: 0.0079 - accuracy: 0.9976 - val_loss: 0.0365 - val_accuracy: 0.9901
# Epoch 10/10
#  - 14s - loss: 0.0066 - accuracy: 0.9980 - val_loss: 0.0684 - val_accuracy: 0.9849
# Fruits-1-conv-64-nodes-2-dense-31052020-123210
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
#  - 24s - loss: 0.4388 - accuracy: 0.8595 - val_loss: 0.2012 - val_accuracy: 0.9270
# Epoch 2/10
#  - 24s - loss: 0.0231 - accuracy: 0.9937 - val_loss: 0.1011 - val_accuracy: 0.9691
# Epoch 3/10
#  - 23s - loss: 0.0100 - accuracy: 0.9972 - val_loss: 0.0881 - val_accuracy: 0.9756
# Epoch 4/10
#  - 25s - loss: 0.0042 - accuracy: 0.9988 - val_loss: 0.1442 - val_accuracy: 0.9600
# Epoch 5/10
#  - 31s - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.1549 - val_accuracy: 0.9687
# Epoch 6/10
#  - 28s - loss: 0.0039 - accuracy: 0.9992 - val_loss: 0.0925 - val_accuracy: 0.9793
# Epoch 7/10
#  - 25s - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.1877 - val_accuracy: 0.9656
# Epoch 8/10
#  - 26s - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.1132 - val_accuracy: 0.9814
# Epoch 9/10
#  - 25s - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.1395 - val_accuracy: 0.9767
# Epoch 10/10
#  - 26s - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.2463 - val_accuracy: 0.9687
# Fruits-2-conv-64-nodes-2-dense-31052020-123628
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
#  - 29s - loss: 0.3813 - accuracy: 0.8758 - val_loss: 0.0752 - val_accuracy: 0.9713
# Epoch 2/10
#  - 27s - loss: 0.0230 - accuracy: 0.9925 - val_loss: 0.0542 - val_accuracy: 0.9836
# Epoch 3/10
#  - 27s - loss: 0.0129 - accuracy: 0.9963 - val_loss: 0.1148 - val_accuracy: 0.9710
# Epoch 4/10
#  - 27s - loss: 0.0110 - accuracy: 0.9979 - val_loss: 0.0436 - val_accuracy: 0.9860
# Epoch 5/10
#  - 26s - loss: 0.0082 - accuracy: 0.9983 - val_loss: 0.0653 - val_accuracy: 0.9870
# Epoch 6/10
#  - 28s - loss: 0.0049 - accuracy: 0.9988 - val_loss: 0.0656 - val_accuracy: 0.9867
# Epoch 7/10
#  - 28s - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.1117 - val_accuracy: 0.9861
# Epoch 8/10
#  - 27s - loss: 0.0050 - accuracy: 0.9989 - val_loss: 0.1545 - val_accuracy: 0.9716
# Epoch 9/10
#  - 28s - loss: 0.0048 - accuracy: 0.9991 - val_loss: 0.1319 - val_accuracy: 0.9827
# Epoch 10/10
#  - 30s - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0957 - val_accuracy: 0.9880
# Fruits-3-conv-64-nodes-2-dense-31052020-124105
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
#  - 31s - loss: 0.5213 - accuracy: 0.8235 - val_loss: 0.3789 - val_accuracy: 0.9041
# Epoch 2/10
#  - 32s - loss: 0.0429 - accuracy: 0.9871 - val_loss: 0.0550 - val_accuracy: 0.9789
# Epoch 3/10
#  - 35s - loss: 0.0206 - accuracy: 0.9947 - val_loss: 0.0352 - val_accuracy: 0.9854
# Epoch 4/10
#  - 51s - loss: 0.0137 - accuracy: 0.9962 - val_loss: 0.0362 - val_accuracy: 0.9909
# Epoch 5/10
#  - 44s - loss: 0.0124 - accuracy: 0.9974 - val_loss: 0.0764 - val_accuracy: 0.9893
# Epoch 6/10
#  - 32s - loss: 0.0092 - accuracy: 0.9979 - val_loss: 0.0819 - val_accuracy: 0.9861
# Epoch 7/10
#  - 29s - loss: 0.0109 - accuracy: 0.9976 - val_loss: 0.1092 - val_accuracy: 0.9871
# Epoch 8/10
#  - 27s - loss: 0.0057 - accuracy: 0.9990 - val_loss: 0.0541 - val_accuracy: 0.9901
# Epoch 9/10
#  - 27s - loss: 0.0066 - accuracy: 0.9986 - val_loss: 0.1110 - val_accuracy: 0.9853
# Epoch 10/10
#  - 28s - loss: 0.0066 - accuracy: 0.9988 - val_loss: 0.0851 - val_accuracy: 0.9890
# Fruits-1-conv-128-nodes-2-dense-31052020-124642
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
#  - 70s - loss: 0.2604 - accuracy: 0.9183 - val_loss: 0.0861 - val_accuracy: 0.9710
# Epoch 2/10
#  - 70s - loss: 0.0133 - accuracy: 0.9965 - val_loss: 0.0835 - val_accuracy: 0.9794
# Epoch 3/10
#  - 64s - loss: 0.0050 - accuracy: 0.9989 - val_loss: 0.1337 - val_accuracy: 0.9731
# Epoch 4/10
#  - 64s - loss: 0.0052 - accuracy: 0.9991 - val_loss: 0.0956 - val_accuracy: 0.9814
# Epoch 5/10
#  - 67s - loss: 0.0033 - accuracy: 0.9994 - val_loss: 0.1028 - val_accuracy: 0.9817
# Epoch 6/10
#  - 71s - loss: 0.0027 - accuracy: 0.9995 - val_loss: 0.1424 - val_accuracy: 0.9821
# Epoch 7/10
#  - 71s - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.1738 - val_accuracy: 0.9766
# Epoch 8/10
#  - 66s - loss: 0.0046 - accuracy: 0.9994 - val_loss: 0.2632 - val_accuracy: 0.9770
# Epoch 9/10
#  - 63s - loss: 0.0059 - accuracy: 0.9993 - val_loss: 0.1730 - val_accuracy: 0.9776
# Epoch 10/10
#  - 63s - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.2373 - val_accuracy: 0.9673
# Fruits-2-conv-128-nodes-2-dense-31052020-125753
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
#  - 57s - loss: 0.2911 - accuracy: 0.9060 - val_loss: 2.0389 - val_accuracy: 0.6736
# Epoch 2/10
#  - 56s - loss: 0.0234 - accuracy: 0.9946 - val_loss: 0.0316 - val_accuracy: 0.9884
# Epoch 3/10
#  - 53s - loss: 0.0130 - accuracy: 0.9969 - val_loss: 0.0463 - val_accuracy: 0.9907
# Epoch 4/10
#  - 56s - loss: 0.0121 - accuracy: 0.9979 - val_loss: 0.0398 - val_accuracy: 0.9877
# Epoch 5/10
#  - 63s - loss: 0.0044 - accuracy: 0.9993 - val_loss: 0.0225 - val_accuracy: 0.9943
# Epoch 6/10
#  - 61s - loss: 0.0067 - accuracy: 0.9991 - val_loss: 0.0579 - val_accuracy: 0.9887
# Epoch 7/10
#  - 57s - loss: 0.0063 - accuracy: 0.9992 - val_loss: 0.1756 - val_accuracy: 0.9800
# Epoch 8/10
#  - 72s - loss: 0.0045 - accuracy: 0.9995 - val_loss: 0.1061 - val_accuracy: 0.9877
# Epoch 9/10
#  - 62s - loss: 0.0067 - accuracy: 0.9992 - val_loss: 0.1943 - val_accuracy: 0.9817
# Epoch 10/10
#  - 63s - loss: 0.0030 - accuracy: 0.9996 - val_loss: 0.1222 - val_accuracy: 0.9880
# Fruits-3-conv-128-nodes-2-dense-31052020-130755
# Compiled!
# Train on 27908 samples, validate on 7000 samples
# Epoch 1/10
# E:\ProgramData\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.139455). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
#  - 59s - loss: 0.3877 - accuracy: 0.8680 - val_loss: 0.1759 - val_accuracy: 0.9384
# Epoch 2/10
#  - 57s - loss: 0.0406 - accuracy: 0.9896 - val_loss: 0.6146 - val_accuracy: 0.8983
# Epoch 3/10
#  - 56s - loss: 0.0247 - accuracy: 0.9948 - val_loss: 0.0730 - val_accuracy: 0.9886
# Epoch 4/10
#  - 56s - loss: 0.0195 - accuracy: 0.9970 - val_loss: 0.1418 - val_accuracy: 0.9776
# Epoch 5/10
#  - 55s - loss: 0.0176 - accuracy: 0.9973 - val_loss: 0.5649 - val_accuracy: 0.9333
# Epoch 6/10
#  - 56s - loss: 0.0119 - accuracy: 0.9983 - val_loss: 0.0834 - val_accuracy: 0.9914
# Epoch 7/10
#  - 55s - loss: 0.0158 - accuracy: 0.9984 - val_loss: 0.0513 - val_accuracy: 0.9894
# Epoch 8/10
#  - 55s - loss: 0.0180 - accuracy: 0.9969 - val_loss: 0.0925 - val_accuracy: 0.9839
# Epoch 9/10
#  - 55s - loss: 0.0038 - accuracy: 0.9993 - val_loss: 0.0675 - val_accuracy: 0.9907
# Epoch 10/10
#  - 52s - loss: 0.0061 - accuracy: 0.9993 - val_loss: 0.0849 - val_accuracy: 0.9901
#
#  Test accuracy: 0.9897216558456421

# %%
dense_layers = [0, 1, 2]
layer_sizes = [32, 64, 128]
conv_layers = [1, 2, 3]

for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME = "Fruits-{}-conv-{}-nodes-{}-dense-{}".format(conv_layer, layer_size, dense_layer, datetime.now().strftime("%d%m%Y-%H%M%S"))
            print(NAME)
# Out:
# Fruits-1-conv-32-nodes-0-dense-29052020-162541
# Fruits-2-conv-32-nodes-0-dense-29052020-162541
# Fruits-3-conv-32-nodes-0-dense-29052020-162541
# Fruits-1-conv-64-nodes-0-dense-29052020-162541
# Fruits-2-conv-64-nodes-0-dense-29052020-162541
# Fruits-3-conv-64-nodes-0-dense-29052020-162541
# Fruits-1-conv-128-nodes-0-dense-29052020-162541
# Fruits-2-conv-128-nodes-0-dense-29052020-162541
# Fruits-3-conv-128-nodes-0-dense-29052020-162541
# Fruits-1-conv-32-nodes-1-dense-29052020-162541
# Fruits-2-conv-32-nodes-1-dense-29052020-162541
# Fruits-3-conv-32-nodes-1-dense-29052020-162541
# Fruits-1-conv-64-nodes-1-dense-29052020-162541
# Fruits-2-conv-64-nodes-1-dense-29052020-162541
# Fruits-3-conv-64-nodes-1-dense-29052020-162541
# Fruits-1-conv-128-nodes-1-dense-29052020-162541
# Fruits-2-conv-128-nodes-1-dense-29052020-162541
# Fruits-3-conv-128-nodes-1-dense-29052020-162541
# Fruits-1-conv-32-nodes-2-dense-29052020-162541
# Fruits-2-conv-32-nodes-2-dense-29052020-162541
# Fruits-3-conv-32-nodes-2-dense-29052020-162541
# Fruits-1-conv-64-nodes-2-dense-29052020-162541
# Fruits-2-conv-64-nodes-2-dense-29052020-162541
# Fruits-3-conv-64-nodes-2-dense-29052020-162541
# Fruits-1-conv-128-nodes-2-dense-29052020-162541
# Fruits-2-conv-128-nodes-2-dense-29052020-162541
# Fruits-3-conv-128-nodes-2-dense-29052020-162541

# %%
#Fruits-1-conv-128-nodes-1-dense-29052020-162541
